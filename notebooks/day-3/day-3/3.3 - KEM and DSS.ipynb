# %% [markdown]
# # Key Encapsulation Mechanism (KEM)
#
# References:
#
# - [wikipedia](https://en.wikipedia.org/wiki/Key_encapsulation_mechanism)
#
# A KEM consists of three algorithms:
#
# - **Key Generation**:  ${\displaystyle ({\mathit {pk}},{\mathit {sk}}):=\operatorname {Keygen} ()}$, takes no inputs and returns a pair of a public key ${\displaystyle {\mathit {pk}}}$ and a private key ${\displaystyle {\mathit {sk}}}$.
#
# - **Encapsulation**: ${\displaystyle (k,c):=\operatorname {Encap} ({\mathit {pk}})}$, takes a public key ${\displaystyle {\mathit {pk}}}$, randomly chooses a secret key ${\displaystyle k}$, and returns ${\displaystyle k}$ along with its encapsulation ${\displaystyle c}$.
#
# - **Decapsulation**: ${\displaystyle (k):=\operatorname {Decap} ({\mathit {sk}, \mathit{c}})}$, takes a private key ${\displaystyle {\mathit {sk}}}$ and an encapsulation ${\displaystyle c'}$, and either returns an encapsulated secret key ${\displaystyle k'}$ or fails, sometimes denoted by returning ${\displaystyle \bot }$.
#
#
# The figure below show the difference between Public-Key Encryption (A) and Key Encapsulation Mechanism (B).
#
# <div style="display:flex; text-align:center; justify-content: center; gap: 30px;">
#
#   <div style="width: 250px; text-align: center;">
#     <p><b>(A) PKE </b></p>
#     <img src="imgs/PKE.png" style="width: 200; height: auto;">
#   </div>
#
#   <div style="width: 225px; text-align: center;">
#     <p><b>(B) KEM </b></p>
#     <img src="imgs/KEM.png" style="width: 200; height: auto;">
#   </div>
#
# </div>

# %%
from IPython.display import IFrame
from kem import print_kem_table

print_kem_table()
IFrame(src="https://pqshield.github.io/nist-sigs-zoo/kems", width=800, height=600)
# Out:
# ====================================================================================================
#  AVAILABLE KEMS
# ====================================================================================================
# <style type="text/css">
# #T_ac776_row0_col0, #T_ac776_row1_col0, #T_ac776_row2_col0, #T_ac776_row3_col0, #T_ac776_row4_col0, #T_ac776_row5_col0, #T_ac776_row6_col0, #T_ac776_row7_col0, #T_ac776_row8_col0, #T_ac776_row9_col0, #T_ac776_row10_col0, #T_ac776_row11_col0, #T_ac776_row12_col0, #T_ac776_row13_col0, #T_ac776_row14_col0, #T_ac776_row15_col0, #T_ac776_row16_col0, #T_ac776_row17_col0 {
#   text-align: left;
# }
# #T_ac776_row0_col1, #T_ac776_row0_col2, #T_ac776_row0_col3, #T_ac776_row0_col4, #T_ac776_row0_col5, #T_ac776_row1_col1, #T_ac776_row1_col2, #T_ac776_row1_col3, #T_ac776_row1_col4, #T_ac776_row1_col5, #T_ac776_row2_col1, #T_ac776_row2_col2, #T_ac776_row2_col3, #T_ac776_row2_col4, #T_ac776_row2_col5, #T_ac776_row3_col1, #T_ac776_row3_col2, #T_ac776_row3_col3, #T_ac776_row3_col4, #T_ac776_row3_col5, #T_ac776_row4_col1, #T_ac776_row4_col2, #T_ac776_row4_col3, #T_ac776_row4_col4, #T_ac776_row4_col5, #T_ac776_row5_col1, #T_ac776_row5_col2, #T_ac776_row5_col3, #T_ac776_row5_col4, #T_ac776_row5_col5, #T_ac776_row6_col1, #T_ac776_row6_col2, #T_ac776_row6_col3, #T_ac776_row6_col4, #T_ac776_row6_col5, #T_ac776_row7_col1, #T_ac776_row7_col2, #T_ac776_row7_col3, #T_ac776_row7_col4, #T_ac776_row7_col5, #T_ac776_row8_col1, #T_ac776_row8_col2, #T_ac776_row8_col3, #T_ac776_row8_col4, #T_ac776_row8_col5, #T_ac776_row9_col1, #T_ac776_row9_col2, #T_ac776_row9_col3, #T_ac776_row9_col4, #T_ac776_row9_col5, #T_ac776_row10_col1, #T_ac776_row10_col2, #T_ac776_row10_col3, #T_ac776_row10_col4, #T_ac776_row10_col5, #T_ac776_row11_col1, #T_ac776_row11_col2, #T_ac776_row11_col3, #T_ac776_row11_col4, #T_ac776_row11_col5, #T_ac776_row12_col1, #T_ac776_row12_col2, #T_ac776_row12_col3, #T_ac776_row12_col4, #T_ac776_row12_col5, #T_ac776_row13_col1, #T_ac776_row13_col2, #T_ac776_row13_col3, #T_ac776_row13_col4, #T_ac776_row13_col5, #T_ac776_row14_col1, #T_ac776_row14_col2, #T_ac776_row14_col3, #T_ac776_row14_col4, #T_ac776_row14_col5, #T_ac776_row15_col1, #T_ac776_row15_col2, #T_ac776_row15_col3, #T_ac776_row15_col4, #T_ac776_row15_col5, #T_ac776_row16_col1, #T_ac776_row16_col2, #T_ac776_row16_col3, #T_ac776_row16_col4, #T_ac776_row16_col5, #T_ac776_row17_col1, #T_ac776_row17_col2, #T_ac776_row17_col3, #T_ac776_row17_col4, #T_ac776_row17_col5 {
#   text-align: right;
# }
# </style>
# <table id="T_ac776">
#   <thead>
#     <tr>
#       <th id="T_ac776_level0_col0" class="col_heading level0 col0" >Algorithm</th>
#       <th id="T_ac776_level0_col1" class="col_heading level0 col1" >NIST Level</th>
#       <th id="T_ac776_level0_col2" class="col_heading level0 col2" >Public key (bytes)</th>
#       <th id="T_ac776_level0_col3" class="col_heading level0 col3" >Secret key (bytes)</th>
#       <th id="T_ac776_level0_col4" class="col_heading level0 col4" >Ciphertext (bytes)</th>
#       <th id="T_ac776_level0_col5" class="col_heading level0 col5" >Shared secret (bytes)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ac776_row0_col0" class="data row0 col0" >ML-KEM-512</td>
#       <td id="T_ac776_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_ac776_row0_col2" class="data row0 col2" >800</td>
#       <td id="T_ac776_row0_col3" class="data row0 col3" >1,632</td>
#       <td id="T_ac776_row0_col4" class="data row0 col4" >768</td>
#       <td id="T_ac776_row0_col5" class="data row0 col5" >32</td>
#     </tr>
#     <tr>
#       <td id="T_ac776_row1_col0" class="data row1 col0" >ML-KEM-768</td>
#       <td id="T_ac776_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_ac776_row1_col2" class="data row1 col2" >1,184</td>
#       <td id="T_ac776_row1_col3" class="data row1 col3" >2,400</td>
#       <td id="T_ac776_row1_col4" class="data row1 col4" >1,088</td>
#       <td id="T_ac776_row1_col5" class="data row1 col5" >32</td>
#     </tr>
#     <tr>
#       <td id="T_ac776_row2_col0" class="data row2 col0" >ML-KEM-1024</td>
#       <td id="T_ac776_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_ac776_row2_col2" class="data row2 col2" >1,568</td>
#       <td id="T_ac776_row2_col3" class="data row2 col3" >3,168</td>
#       <td id="T_ac776_row2_col4" class="data row2 col4" >1,568</td>
#       <td id="T_ac776_row2_col5" class="data row2 col5" >32</td>
#     </tr>
#     <tr>
#       <td id="T_ac776_row3_col0" class="data row3 col0" >BIKE-L1</td>
#       <td id="T_ac776_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_ac776_row3_col2" class="data row3 col2" >1,541</td>
#       <td id="T_ac776_row3_col3" class="data row3 col3" >5,223</td>
#       <td id="T_ac776_row3_col4" class="data row3 col4" >1,573</td>
#       <td id="T_ac776_row3_col5" class="data row3 col5" >32</td>
#     </tr>
#     <tr>
#       <td id="T_ac776_row4_col0" class="data row4 col0" >BIKE-L3</td>
#       <td id="T_ac776_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_ac776_row4_col2" class="data row4 col2" >3,083</td>
#       <td id="T_ac776_row4_col3" class="data row4 col3" >10,105</td>
#       <td id="T_ac776_row4_col4" class="data row4 col4" >3,115</td>
#       <td id="T_ac776_row4_col5" class="data row4 col5" >32</td>
#     </tr>
#     <tr>
#       <td id="T_ac776_row5_col0" class="data row5 col0" >BIKE-L5</td>
#       <td id="T_ac776_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_ac776_row5_col2" class="data row5 col2" >5,122</td>
#       <td id="T_ac776_row5_col3" class="data row5 col3" >16,494</td>
#       <td id="T_ac776_row5_col4" class="data row5 col4" >5,154</td>
#       <td id="T_ac776_row5_col5" class="data row5 col5" >32</td>
#     </tr>
#     <tr>
#       <td id="T_ac776_row6_col0" class="data row6 col0" >HQC-1</td>
#       <td id="T_ac776_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_ac776_row6_col2" class="data row6 col2" >2,241</td>
#       <td id="T_ac776_row6_col3" class="data row6 col3" >2,321</td>
#       <td id="T_ac776_row6_col4" class="data row6 col4" >4,433</td>
#       <td id="T_ac776_row6_col5" class="data row6 col5" >32</td>
#     </tr>
#     <tr>
#       <td id="T_ac776_row7_col0" class="data row7 col0" >HQC-3</td>
#       <td id="T_ac776_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_ac776_row7_col2" class="data row7 col2" >4,514</td>
#       <td id="T_ac776_row7_col3" class="data row7 col3" >4,602</td>
#       <td id="T_ac776_row7_col4" class="data row7 col4" >8,978</td>
#       <td id="T_ac776_row7_col5" class="data row7 col5" >32</td>
#     </tr>
#     <tr>
#       <td id="T_ac776_row8_col0" class="data row8 col0" >HQC-5</td>
#       <td id="T_ac776_row8_col1" class="data row8 col1" >5</td>
#       <td id="T_ac776_row8_col2" class="data row8 col2" >7,237</td>
#       <td id="T_ac776_row8_col3" class="data row8 col3" >7,333</td>
#       <td id="T_ac776_row8_col4" class="data row8 col4" >14,421</td>
#       <td id="T_ac776_row8_col5" class="data row8 col5" >32</td>
#     </tr>
#     <tr>
#       <td id="T_ac776_row9_col0" class="data row9 col0" >FrodoKEM-640-AES</td>
#       <td id="T_ac776_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_ac776_row9_col2" class="data row9 col2" >9,616</td>
#       <td id="T_ac776_row9_col3" class="data row9 col3" >19,888</td>
#       <td id="T_ac776_row9_col4" class="data row9 col4" >9,752</td>
#       <td id="T_ac776_row9_col5" class="data row9 col5" >16</td>
#     </tr>
#     <tr>
#       <td id="T_ac776_row10_col0" class="data row10 col0" >FrodoKEM-976-AES</td>
#       <td id="T_ac776_row10_col1" class="data row10 col1" >3</td>
#       <td id="T_ac776_row10_col2" class="data row10 col2" >15,632</td>
#       <td id="T_ac776_row10_col3" class="data row10 col3" >31,296</td>
#       <td id="T_ac776_row10_col4" class="data row10 col4" >15,792</td>
#       <td id="T_ac776_row10_col5" class="data row10 col5" >24</td>
#     </tr>
#     <tr>
#       <td id="T_ac776_row11_col0" class="data row11 col0" >FrodoKEM-1344-AES</td>
#       <td id="T_ac776_row11_col1" class="data row11 col1" >5</td>
#       <td id="T_ac776_row11_col2" class="data row11 col2" >21,520</td>
#       <td id="T_ac776_row11_col3" class="data row11 col3" >43,088</td>
#       <td id="T_ac776_row11_col4" class="data row11 col4" >21,696</td>
#       <td id="T_ac776_row11_col5" class="data row11 co
#         <iframe
#             width="800"
#             height="600"
#             src="https://pqshield.github.io/nist-sigs-zoo/kems"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import oqs

def short_hex(data, n=40):
    hex_data = data.hex()
    return hex_data[:n * 2] + "..."


BLUE = "\033[94m"
RED = "\033[91m"
GREEN = "\033[92m"
RESET = "\033[0m"

KEM = "ML-KEM-512"
kem = oqs.KeyEncapsulation(KEM)
bob_public_key = kem.generate_keypair()


print("[BOB] Generata la coppia di chiavi")
print(f"[BOB] Public key: {BLUE}0x{short_hex(bob_public_key)}{RESET}")

print()
print("[BOB]   ------ pk ----->  [ALICE]")
print()

print("[ALICE] Ricevuta la public key di Bob")
print("[ALICE] Eseguo encapsulation...")

ciphertext, alice_shared_secret = kem.encap_secret(bob_public_key)

print(f"[ALICE] Ciphertext: {RED}0x{short_hex(ciphertext)}{RESET}")
print(f"[ALICE] Shared secret: {GREEN}0x{alice_shared_secret.hex()}{RESET}")


print()
print("[BOB]   <------ ct -----  [ALICE]")
print()

print("[BOB] Ricevuto il ciphertext")
print("[BOB] Eseguo decapsulation...")

bob_shared_secret = kem.decap_secret(ciphertext)

print(f"[BOB] Shared secret: {GREEN}0x{bob_shared_secret.hex()}{RESET}")
print()


# ============================================================
# VERIFICA
# ============================================================

if alice_shared_secret == bob_shared_secret:
    print("✓ Alice e Bob possiedono la stessa shared secret")
else:
    print("✗ Errore: le shared secret sono diverse")


ciphertext_modified = bytearray(ciphertext)

# Modifichiamo il primo byte
ciphertext_modified[0] ^= 1

ciphertext_modified = bytes(ciphertext_modified)

print("[ATTACKER] ⚠ Ciphertext modificato!")
print(f"[ATTACKER] Originale: {ciphertext.hex()[:32]}...")
print(f"[ATTACKER] Modificato: {ciphertext_modified.hex()[:32]}...")

secret_modified = kem.decap_secret(ciphertext_modified)

print("[BOB] Decapsulation del ciphertext modificato")
print(f"[BOB] Shared secret: {secret_modified.hex()}")

print("\nShared secret originale == modificata:",
      alice_shared_secret == secret_modified)
# Out:
# [BOB] Generata la coppia di chiavi
# [BOB] Public key: 0x3bb7bca148a9659069d540391d21813d602a3a192e8b086f7fa77c32181097bb4a60823a1f720358...
#
# [BOB]   ------ pk ----->  [ALICE]
#
# [ALICE] Ricevuta la public key di Bob
# [ALICE] Eseguo encapsulation...
# [ALICE] Ciphertext: 0x781d8bf1880cb388896c24a04b5d2f27fc327e889f9e09368ba25739bef8900ceab8bdf0491d7f31...
# [ALICE] Shared secret: 0xedee6971ee85a3a4accd813955024d371a23d346984275684eb03cb770ec03f0
#
# [BOB]   <------ ct -----  [ALICE]
#
# [BOB] Ricevuto il ciphertext
# [BOB] Eseguo decapsulation...
# [BOB] Shared secret: 0xedee6971ee85a3a4accd813955024d371a23d346984275684eb03cb770ec03f0
#
# ✓ Alice e Bob possiedono la stessa shared secret
# [ATTACKER] ⚠ Ciphertext modificato!
# [ATTACKER] Originale: 781d8bf1880cb388896c24a04b5d2f27...
# [ATTACKER] Modificato: 791d8bf1880cb388896c24a04b5d2f27...
# [BOB] Decapsulation del ciphertext modificato
# [BOB] Shared secret: 8d1f260f6af27ffad88703cc192ae694e99809183761daadb1c83289a07f5746
#
# Shared secret originale == modificata: False

# %% [markdown]
# Determinismo della decapsulation — invia lo stesso ciphertext due volte a decap_secret: il segreto restituito è identico (la decap è deterministica, a differenza dell'encap che è randomizzata). Buono spunto di discussione: un ciphertext è "replayable" a livello di primitiva — è il protocollo sopra (TLS, ecc.) che deve garantire freschezza con nonce/timestamp, non il KEM da solo.

# %% [markdown]
# # Digital Signature Scheme (DSS)
#
# - Keygen
# - Sign
# - Verify

# %%
from dss import print_dss_table
from IPython.display import IFrame

print_dss_table()
IFrame(src="https://pqshield.github.io/nist-sigs-zoo", width=800, height=600)
# Out:
# liboqs-python faulthandler is disabled
# ====================================================================================================
#  AVAILABLE DIGITAL SIGNATURE SCHEMES
# ====================================================================================================
# <style type="text/css">
# #T_81694_row0_col0, #T_81694_row1_col0, #T_81694_row2_col0, #T_81694_row3_col0, #T_81694_row4_col0, #T_81694_row5_col0, #T_81694_row6_col0, #T_81694_row7_col0, #T_81694_row8_col0, #T_81694_row9_col0, #T_81694_row10_col0, #T_81694_row11_col0, #T_81694_row12_col0, #T_81694_row13_col0, #T_81694_row14_col0 {
#   text-align: left;
# }
# #T_81694_row0_col1, #T_81694_row0_col2, #T_81694_row0_col3, #T_81694_row0_col4, #T_81694_row1_col1, #T_81694_row1_col2, #T_81694_row1_col3, #T_81694_row1_col4, #T_81694_row2_col1, #T_81694_row2_col2, #T_81694_row2_col3, #T_81694_row2_col4, #T_81694_row3_col1, #T_81694_row3_col2, #T_81694_row3_col3, #T_81694_row3_col4, #T_81694_row4_col1, #T_81694_row4_col2, #T_81694_row4_col3, #T_81694_row4_col4, #T_81694_row5_col1, #T_81694_row5_col2, #T_81694_row5_col3, #T_81694_row5_col4, #T_81694_row6_col1, #T_81694_row6_col2, #T_81694_row6_col3, #T_81694_row6_col4, #T_81694_row7_col1, #T_81694_row7_col2, #T_81694_row7_col3, #T_81694_row7_col4, #T_81694_row8_col1, #T_81694_row8_col2, #T_81694_row8_col3, #T_81694_row8_col4, #T_81694_row9_col1, #T_81694_row9_col2, #T_81694_row9_col3, #T_81694_row9_col4, #T_81694_row10_col1, #T_81694_row10_col2, #T_81694_row10_col3, #T_81694_row10_col4, #T_81694_row11_col1, #T_81694_row11_col2, #T_81694_row11_col3, #T_81694_row11_col4, #T_81694_row12_col1, #T_81694_row12_col2, #T_81694_row12_col3, #T_81694_row12_col4, #T_81694_row13_col1, #T_81694_row13_col2, #T_81694_row13_col3, #T_81694_row13_col4, #T_81694_row14_col1, #T_81694_row14_col2, #T_81694_row14_col3, #T_81694_row14_col4 {
#   text-align: right;
# }
# </style>
# <table id="T_81694">
#   <thead>
#     <tr>
#       <th id="T_81694_level0_col0" class="col_heading level0 col0" >Algorithm</th>
#       <th id="T_81694_level0_col1" class="col_heading level0 col1" >NIST Level</th>
#       <th id="T_81694_level0_col2" class="col_heading level0 col2" >Public key (bytes)</th>
#       <th id="T_81694_level0_col3" class="col_heading level0 col3" >Secret key (bytes)</th>
#       <th id="T_81694_level0_col4" class="col_heading level0 col4" >Signature (bytes)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_81694_row0_col0" class="data row0 col0" >ML-DSA-44</td>
#       <td id="T_81694_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_81694_row0_col2" class="data row0 col2" >1,312</td>
#       <td id="T_81694_row0_col3" class="data row0 col3" >2,560</td>
#       <td id="T_81694_row0_col4" class="data row0 col4" >2,420</td>
#     </tr>
#     <tr>
#       <td id="T_81694_row1_col0" class="data row1 col0" >ML-DSA-65</td>
#       <td id="T_81694_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_81694_row1_col2" class="data row1 col2" >1,952</td>
#       <td id="T_81694_row1_col3" class="data row1 col3" >4,032</td>
#       <td id="T_81694_row1_col4" class="data row1 col4" >3,309</td>
#     </tr>
#     <tr>
#       <td id="T_81694_row2_col0" class="data row2 col0" >ML-DSA-87</td>
#       <td id="T_81694_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_81694_row2_col2" class="data row2 col2" >2,592</td>
#       <td id="T_81694_row2_col3" class="data row2 col3" >4,896</td>
#       <td id="T_81694_row2_col4" class="data row2 col4" >4,627</td>
#     </tr>
#     <tr>
#       <td id="T_81694_row3_col0" class="data row3 col0" >MAYO-1</td>
#       <td id="T_81694_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_81694_row3_col2" class="data row3 col2" >1,420</td>
#       <td id="T_81694_row3_col3" class="data row3 col3" >24</td>
#       <td id="T_81694_row3_col4" class="data row3 col4" >454</td>
#     </tr>
#     <tr>
#       <td id="T_81694_row4_col0" class="data row4 col0" >MAYO-2</td>
#       <td id="T_81694_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_81694_row4_col2" class="data row4 col2" >4,912</td>
#       <td id="T_81694_row4_col3" class="data row4 col3" >24</td>
#       <td id="T_81694_row4_col4" class="data row4 col4" >186</td>
#     </tr>
#     <tr>
#       <td id="T_81694_row5_col0" class="data row5 col0" >MAYO-3</td>
#       <td id="T_81694_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_81694_row5_col2" class="data row5 col2" >2,986</td>
#       <td id="T_81694_row5_col3" class="data row5 col3" >32</td>
#       <td id="T_81694_row5_col4" class="data row5 col4" >681</td>
#     </tr>
#     <tr>
#       <td id="T_81694_row6_col0" class="data row6 col0" >MAYO-5</td>
#       <td id="T_81694_row6_col1" class="data row6 col1" >5</td>
#       <td id="T_81694_row6_col2" class="data row6 col2" >5,554</td>
#       <td id="T_81694_row6_col3" class="data row6 col3" >40</td>
#       <td id="T_81694_row6_col4" class="data row6 col4" >964</td>
#     </tr>
#     <tr>
#       <td id="T_81694_row7_col0" class="data row7 col0" >SLH_DSA_PURE_SHA2_128S</td>
#       <td id="T_81694_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_81694_row7_col2" class="data row7 col2" >32</td>
#       <td id="T_81694_row7_col3" class="data row7 col3" >64</td>
#       <td id="T_81694_row7_col4" class="data row7 col4" >7,856</td>
#     </tr>
#     <tr>
#       <td id="T_81694_row8_col0" class="data row8 col0" >SLH_DSA_PURE_SHA2_192S</td>
#       <td id="T_81694_row8_col1" class="data row8 col1" >3</td>
#       <td id="T_81694_row8_col2" class="data row8 col2" >48</td>
#       <td id="T_81694_row8_col3" class="data row8 col3" >96</td>
#       <td id="T_81694_row8_col4" class="data row8 col4" >16,224</td>
#     </tr>
#     <tr>
#       <td id="T_81694_row9_col0" class="data row9 col0" >SLH_DSA_PURE_SHA2_256S</td>
#       <td id="T_81694_row9_col1" class="data row9 col1" >5</td>
#       <td id="T_81694_row9_col2" class="data row9 col2" >64</td>
#       <td id="T_81694_row9_col3" class="data row9 col3" >128</td>
#       <td id="T_81694_row9_col4" class="data row9 col4" >29,792</td>
#     </tr>
#     <tr>
#       <td id="T_81694_row10_col0" class="data row10 col0" >cross-rsdp-128-balanced</td>
#       <td id="T_81694_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_81694_row10_col2" class="data row10 col2" >77</td>
#       <td id="T_81694_row10_col3" class="data row10 col3" >32</td>
#       <td id="T_81694_row10_col4" class="data row10 col4" >13,152</td>
#     </tr>
#     <tr>
#       <td id="T_81694_row11_col0" class="data row11 col0" >cross-rsdp-192-balanced</td>
#       <td id="T_81694_row11_col1" class="data row11 col1" >3</td>
#       <td id="T_81694_row11_col2" class="data row11 col2" >115</td>
#       <td id="T_81694_row11_col3" class="data row11 col3" >48</td>
#       <td id="T_81694_row11_col4" class="data row11 col4" >29,853</td>
#     </tr>
#     <tr>
#       <td id="T_81694_row12_col0" class="data row12 col0" >cross-rsdp-256-balanced</td>
#       <td id="T_81694_row12_col1" class="data row12 col1" >5</td>
#       <td id="T_81694_row12_col2" class="data row12 col2" >153</td>
#       <td id="T_81694_row12_col3" class="data row12 col3" >64</td>
#       <td id="T_81694_row12_col4" class="data row12 col4" >53,527</td>
#     </tr>
#     <tr>
#       <td id="T_81694_row13_col0" class="data row13 col0" >Falcon-512</td>
#       <td id="T_81694_row13_col1" class="data row13 col1" >1</td>
#       <td id="T_81694_row13_col2" class="data row13 col2" >897</td>
#       <td id="T_81694_row13_col3" class="data row13 col3" >1,281</td>
#       <td id="T_81694_row13_col4" class="data row13 col4" >752</td>
#     </tr>
#     <tr>
#       <td id="T_81694_row14_col0" class="data row14 col0" >Falcon-1024</td>
#       <td id="T_81694_row14_col1" class="data row14 col1" >5</td>
#       <td id="T_81694_row14_col2" class="data row14 col2" >1,793</td>
#       <td id="T_81694_row14_col3" class="data row14 col3" >2,305</td>
#       <td id="T_81694_row14_col4" class="data row14 col4" >1,462</td>
#     </tr>
#   </tbody>
# </table>
#         <iframe
#             width="800"
#             height="600"
#             src="https://pqshield.github.io/nist-sigs-zoo"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from sys import stdout
import oqs as oqs
import json

message = b"This is the message to sign"
sigalg = "ML-DSA-44"

with oqs.Signature(sigalg) as signer, oqs.Signature(sigalg) as verifier:
    
    print("Signature details:")
    print(json.dumps(signer.details, indent=4, ensure_ascii=False))

    # Signer generates its keypair
    signer_public_key = signer.generate_keypair()
    secret_key = signer.export_secret_key()
    print("=" * 70)
    print("Generated public key")
    print("=" * 70)
    print(signer_public_key.hex())
    print()
    print("=" * 70)
    print("Generated secret key")
    print("=" * 70)
    print(secret_key.hex())

    # Store key pair, wait... (session resumption):
    # signer = oqs.Signature(sigalg, secret_key)

    # Signer signs the message
    signature = signer.sign(message)

    # Verifier verifies the signature
    is_valid = verifier.verify(message, signature, signer_public_key)

    print(is_valid)
# Out:
# Signature details:
# {
#     "name": "ML-DSA-44",
#     "version": "FIPS204",
#     "claimed_nist_level": 2,
#     "is_euf_cma": true,
#     "is_suf_cma": false,
#     "supports_context_signing": true,
#     "sig_with_ctx_support": true,
#     "length_public_key": 1312,
#     "length_secret_key": 2560,
#     "length_signature": 2420
# }
# ======================================================================
# Generated public key
# ======================================================================
# ...
#
# ======================================================================
# Generated secret key
# ======================================================================
# ...
# True
