# %%
import time
import statistics
import oqs

# %%
# Out:
#      Algorithm  KeyGen (µs)  Encapsulation (µs)  Decapsulation (µs)
# 0   ML-KEM-512        5.431              6.2320              6.0310
# 1   ML-KEM-768        8.105              8.9470              9.2080
# 2  ML-KEM-1024        9.758             10.8000             11.7520
# 3      BIKE-L1      158.061             24.1355            356.3415
