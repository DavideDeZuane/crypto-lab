# %% [markdown]
# Ok ora vorrei introdurre il concetto di funzione trapdoor, questo e' molto sensato perche' praticamente merkle puzzle e' una one way function infatti lo sforzo che c'e' tra l'attaccante e l'utente legittimo non e' cosi diverso. Quindi dobbiamo trovare un problema che per un attaccante sia difficile ma che per l'utente legittimo sia facile quindi la definizione di trapdoor con un grafico che spiega questa cosa e vorrei fare anche un esempio.
#
# Poi dire che per trovare problemi che ci garantiscano questa properita' andiamo a vedere l'aritmetica modulare dove infatti abbiamo che grazie alla sue properita' ogni numero ha piu corrispondenze e trovare quella giusta e' quel segreto che rende il problema per l'utente legittimo facile.

# %%
from cryptography.hazmat.primitives.asymmetric import rsa

private_key = rsa.generate_private_key(
    public_exponent=65537,
    key_size=2048
)

public_key = private_key.public_key()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from cryptography.hazmat.primitives.asymmetric import rsa
#       2
#       3 private_key = rsa.generate_private_key(
#       4     public_exponent=65537,
#
# ModuleNotFoundError: No module named 'cryptography'

# %% [markdown]
# ## Esponenziazione veloci
